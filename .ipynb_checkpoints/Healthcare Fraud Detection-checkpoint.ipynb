# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Data Understanding

# %%
df = pd.read_csv("/Users/bethe/Documents/DS Project/Healthcare Fraud/healthcare_fraud_detection.csv")
df.head()
# Out:
#   Provider_ID  Claim_ID  Patient_Age Patient_Gender Diagnosis_Code  \
# 0       P0052  C0000000           37           Male         I25.10
# 1       P0121  C0000001           21         Female          E11.9
# 2       P0140  C0000002           78         Female          J06.9
# 3       P0202  C0000003           65           Male            I10
# 4       P0135  C0000004           36           Male          M54.5
#
#    Procedure_Code  Claim_Amount  Approved_Amount Insurance_Type  \
# 0           36415        443.51           393.16       Medicaid
# 1           99213        467.50           461.33       Self-Pay
# 2           93000        591.69           530.06       Medicaid
# 3           93000        235.15           189.11        Private
# 4           85025        487.96           369.91        Private
#
#   Claim_Submission_Date  Days_Between_Service_and_Claim  \
# 0            2024-09-01                              13
# 1            2022-09-05                               5
# 2            2022-04-11                              29
# 3            2023-10-11                              22
# 4            2023-09-05                              21
#
#    Number_of_Claims_Per_Provider_Monthly Provider_Specialty Patient_State  \
# 0                                     70         Cardiology            NY
# 1                                     62   General Practice            IL
# 2                                     60         Cardiology            IL
# 3                                     70   General Practice            TX
# 4                                     67        Pulmonology            PA
#
#   Claim_Status  Is_Fraud  Length_of_Stay  Visit_Type  Chronic_Condition_Flag  \
# 0     Approved         0               0  Outpatient                       1
# 1      Pending         0               5   Inpatient                       1
# 2      Pending         0               5   Inpatient                       1
# 3     Approved         0               0   Emergency                       0
# 4     Approved         0               5   Inpatient                       0
#
#    Prior_Visits_12m
# 0               2.0
# 1               2.0
# 2               3.0
# 3               5.0
# 4               4.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Provider_ID                            10000 non-null  object
#  1   Claim_ID                               10000 non-null  object
#  2   Patient_Age                            10000 non-null  int64
#  3   Patient_Gender                         10000 non-null  object
#  4   Diagnosis_Code                         10000 non-null  object
#  5   Procedure_Code                         10000 non-null  int64
#  6   Claim_Amount                           10000 non-null  float64
#  7   Approved_Amount                        10000 non-null  float64
#  8   Insurance_Type                         9650 non-null   object
#  9   Claim_Submission_Date                  10000 non-null  object
#  10  Days_Between_Service_and_Claim         10000 non-null  int64
#  11  Number_of_Claims_Per_Provider_Monthly  10000 non-null  int64
#  12  Provider_Specialty                     9650 non-null   object
#  13  Patient_State                          10000 non-null  object
#  14  Claim_Status                           10000 non-null  object
#  15  Is_Fraud                               10000 non-null  int64
#  16  Length_of_Stay                         10000 non-null  int64
#  17  Visit_Type                             10000 non-null  object
#  18  Chronic_Condition_Flag                 10000 non-null  int64
#  19  Prior_Visits_12m                       9650 non-null   float64
# dtypes: float64(3), int64(7), object(10)
# memory usage: 1.5+ MB

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# Provider_ID                              0.0
# Claim_ID                                 0.0
# Patient_Age                              0.0
# Patient_Gender                           0.0
# Diagnosis_Code                           0.0
# Procedure_Code                           0.0
# Claim_Amount                             0.0
# Approved_Amount                          0.0
# Insurance_Type                           3.5
# Claim_Submission_Date                    0.0
# Days_Between_Service_and_Claim           0.0
# Number_of_Claims_Per_Provider_Monthly    0.0
# Provider_Specialty                       3.5
# Patient_State                            0.0
# Claim_Status                             0.0
# Is_Fraud                                 0.0
# Length_of_Stay                           0.0
# Visit_Type                               0.0
# Chronic_Condition_Flag                   0.0
# Prior_Visits_12m                         3.5
# dtype: float64

# %%
df.describe()
# Out:
#         Patient_Age  Procedure_Code  Claim_Amount  Approved_Amount  \
# count  10000.000000     10000.00000  10000.000000     10000.000000
# mean      49.755000     86905.21170    572.804406       475.514157
# std       17.910144     14965.32496    406.202437       323.257165
# min        1.000000     36415.00000     60.210000        50.350000
# 25%       37.750000     80053.00000    305.205000       257.200000
# 50%       50.000000     93000.00000    461.225000       388.370000
# 75%       62.000000     99213.00000    711.365000       598.347500
# max       95.000000     99214.00000   6590.700000      4270.890000
#
#        Days_Between_Service_and_Claim  Number_of_Claims_Per_Provider_Monthly  \
# count                    10000.000000                           10000.000000
# mean                        14.413800                              68.628000
# std                          8.489875                              14.905872
# min                          0.000000                              42.000000
# 25%                          7.000000                              60.000000
# 50%                         14.000000                              66.000000
# 75%                         22.000000                              72.000000
# max                         29.000000                             144.000000
#
#            Is_Fraud  Length_of_Stay  Chronic_Condition_Flag  Prior_Visits_12m
# count  10000.000000     10000.00000            10000.000000       9650.000000
# mean       0.082900         2.19930                0.292000          3.026425
# std        0.275745         1.71046                0.454705          1.722789
# min        0.000000         0.00000                0.000000          0.000000
# 25%        0.000000         1.00000                0.000000          2.000000
# 50%        0.000000         2.00000                0.000000          3.000000
# 75%        0.000000         3.00000                1.000000          4.000000
# max        1.000000         5.00000                1.000000         12.000000

# %%
# Hilangkan kolom yang tidak digunakan

df.drop(['Provider_ID', 'Claim_ID', 'Diagnosis_Code', 'Patient_State', 'Procedure_Code', 'Prior_Visits_12m'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Patient_Age Patient_Gender  Claim_Amount  Approved_Amount Insurance_Type  \
# 0           37           Male        443.51           393.16       Medicaid
# 1           21         Female        467.50           461.33       Self-Pay
# 2           78         Female        591.69           530.06       Medicaid
# 3           65           Male        235.15           189.11        Private
# 4           36           Male        487.96           369.91        Private
#
#   Claim_Submission_Date  Days_Between_Service_and_Claim  \
# 0            2024-09-01                              13
# 1            2022-09-05                               5
# 2            2022-04-11                              29
# 3            2023-10-11                              22
# 4            2023-09-05                              21
#
#    Number_of_Claims_Per_Provider_Monthly Provider_Specialty Claim_Status  \
# 0                                     70         Cardiology     Approved
# 1                                     62   General Practice      Pending
# 2                                     60         Cardiology      Pending
# 3                                     70   General Practice     Approved
# 4                                     67        Pulmonology     Approved
#
#    Is_Fraud  Length_of_Stay  Visit_Type  Chronic_Condition_Flag
# 0         0               0  Outpatient                       1
# 1         0               5   Inpatient                       1
# 2         0               5   Inpatient                       1
# 3         0               0   Emergency                       0
# 4         0               5   Inpatient                       0

# %%
for col in df.select_dtypes('object').columns:
    print(df[col].value_counts())
# Out:
# Patient_Gender
# Female    5001
# Male      4999
# Name: count, dtype: int64
# Insurance_Type
# Medicare    2425
# Medicaid    2419
# Private     2405
# Self-Pay    2401
# Name: count, dtype: int64
# Provider_Specialty
# Internal Medicine    2019
# General Practice     1878
# Orthopedics          1616
# Neurology            1516
# Cardiology           1366
# Pulmonology          1255
# Name: count, dtype: int64
# Claim_Status
# Approved    7053
# Rejected    1748
# Pending     1199
# Name: count, dtype: int64
# Visit_Type
# Outpatient    3423
# Emergency     3368
# Inpatient     3209
# Name: count, dtype: int64

# %%
df['Claim_Submission_Date'] = pd.to_datetime(df['Claim_Submission_Date'], format='%Y-%m-%d')
df['Claim_Submission_mth'] = df['Claim_Submission_Date'].dt.month
df['Claim_Submission_yr'] = df['Claim_Submission_Date'].dt.year

# %% [markdown]
# ### **Exploratory Data Analysis (EDA)**

# %%
fig, ax = plt.subplots()

ax.set_facecolor((0, 0, 0, 0)) #Transparent Background
fig.patch.set_alpha(0.0)

sns.histplot(data=df, x='Patient_Age', hue='Is_Fraud', ax=ax)

plt.title("Distribution of Patient Age")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
df_fr0 = df[df['Is_Fraud'] == 0].groupby(['Claim_Submission_mth'], as_index=False)['Claim_Amount'].median()
df_fr1 = df[df['Is_Fraud'] == 1].groupby(['Claim_Submission_mth'], as_index=False)['Claim_Amount'].median()

fig, ax = plt.subplots()

sns.lineplot(df_fr0, x='Claim_Submission_mth', y='Claim_Amount', ax=ax, label='Not Fraud')
sns.lineplot(df_fr1, x='Claim_Submission_mth', y='Claim_Amount', ax=ax, label='Fraud')

ax.set_facecolor((0, 0, 0, 0)) #Transparent Background
fig.patch.set_alpha(0.0)

plt.title("Claim Submission in a month")
plt.xlabel("Month")
plt.ylabel("Claim Amount")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

ax = sns.countplot(df, x=df['Provider_Specialty'], order=df['Provider_Specialty'].value_counts(ascending=False).index, hue='Is_Fraud')

for cnt in ax.containers:
    ax.bar_label(cnt)

plt.title("Provider Speciality")
plt.xlabel("Provider")
plt.ylabel("Count")
plt.show()

# %%
sns.countplot(df, x='Claim_Status')

plt.title("Claim Status")
plt.xlabel("Status")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Untuk melakukan Machine Learning, akan di ambil data **'Approved'** dan **'Rejected'** sebagai data training

# %% [markdown]
# #### Handling Outlier

# %%
fig, ax = plt.subplots()

sns.boxplot(x=df["Claim_Amount"])

ax.set_facecolor((0, 0, 0, 0)) #Transparent Background
fig.patch.set_alpha(0.0)

plt.title("Boxplot of Claim Amount")
plt.show()

# %%
df[df['Claim_Amount'] > 5000]
# Out:
#      Patient_Age Patient_Gender  Claim_Amount  Approved_Amount Insurance_Type  \
# 507           62         Female        6590.7          4270.89       Self-Pay
#
#     Claim_Submission_Date  Days_Between_Service_and_Claim  \
# 507            2022-01-04                               0
#
#      Number_of_Claims_Per_Provider_Monthly Provider_Specialty Claim_Status  \
# 507                                     94   General Practice     Approved
#
#      Is_Fraud  Length_of_Stay Visit_Type  Chronic_Condition_Flag  \
# 507         1               1  Inpatient                       1
#
#      Claim_Submission_mth  Claim_Submission_yr
# 507                     1                 2022

# %% [markdown]
# Tidak di drop karena merupakan informasi penting, yaitu kemungkinan salah satu bukti tanda Fraud.

# %%
fig, ax = plt.subplots()

sns.boxplot(x=df["Number_of_Claims_Per_Provider_Monthly"])

ax.set_facecolor((0, 0, 0, 0)) #Transparent Background
fig.patch.set_alpha(0.0)

plt.title("Boxplot of Number of Claim Monthly")
plt.show()

# %%
df[df['Number_of_Claims_Per_Provider_Monthly'] > 130]
# Out:
#       Patient_Age Patient_Gender  Claim_Amount  Approved_Amount  \
# 951            34           Male        662.03           448.31
# 1232           36           Male       1032.72           331.08
# 1316           41         Female       1192.77          1055.56
# 1450           63         Female        313.42           309.08
# 1529           65           Male        542.62           441.25
# 2968           22           Male        858.44           726.04
# 4260           64         Female        278.45           215.34
# 4438           43           Male        370.43           152.92
# 4714           34         Female       1182.35           887.54
# 4784           43           Male        703.47           580.91
# 5166           43         Female        273.03           247.13
# 5855           30           Male       1242.96           700.61
# 5928           92           Male        794.56           599.83
# 5938           83         Female        289.13           242.10
# 6284           52         Female        761.10           608.72
# 6471           18         Female        783.18           625.48
# 6710           34           Male       1542.16           485.54
# 7305           34         Female        438.01           343.76
# 7578           56           Male        188.95           153.10
# 7594           58         Female        413.48           388.70
# 8158           46         Female        311.38           135.86
# 8328           57           Male       2298.73           723.98
# 8791           17           Male        460.55           422.09
# 9551           59           Male        856.54           851.74
#
#      Insurance_Type Claim_Submission_Date  Days_Between_Service_and_Claim  \
# 951        Self-Pay            2024-09-15                               1
# 1232       Self-Pay            2023-05-11                               2
# 1316       Self-Pay            2022-02-17                              13
# 1450        Private            2023-01-04                               4
# 1529       Medicare            2024-09-22                              15
# 2968       Medicare            2022-07-27                               6
# 4260       Self-Pay            2021-02-24                              29
# 4438       Self-Pay            2022-07-02                               4
# 4714        Private            2023-02-14                               2
# 4784       Self-Pay            2021-12-02                               8
# 5166        Private            2024-10-17                              25
# 5855       Medicaid            2021-02-28                               0
# 5928        Private            2021-06-05                              18
# 5938       Self-Pay            2021-06-09                              14
# 6284       Medicaid            2023-01-03                              25
# 6471       Self-Pay            2023-06-30                               6
# 6710        Private            2021-07-29                               1
# 7305       Medicare            2022-08-03                              16
# 7578        Private            2021-02-11                              19
# 7594       Medicare            2024-04-03                               6
# 8158       Medicaid            2022-11-23                               1
# 8328       Medicaid            2022-10-11                               4
# 8791       Medicare            2022-10-05                               5
# 9551       Medicare            2024-03-03                              24
#
#       Number_of_Claims_Per_Provider_Monthly Provider_Specialty Claim_Status  \
# 951                                     133   General Practice      Pending
# 1232                                    137        Orthopedics      Pending
# 1316                                    133   General Practice     Approved
# 1450                                    144        Pulmonology     Approved
# 1529                                    132  Internal Medicine      Pending
# 2968                                    132   General Practice     Approved
# 4260                                    132        Pulmonology     Approved
# 4438                                    137        Pulmonology     Approved
# 4714                                    131        Pulmonology      Pending
# 4784                                    134        Pulmonology     Rejected
# 5166                                    133  Internal Medicine     Rejected
# 5855                                    137   General Practice      Pending
# 5928                                    139  Internal Medicine     Approved
# 5938                                    139   General Practice     Rejected
# 6284                                    134   General Practice     Approved
# 6471                                    133   General Practice     Approved
# 6710                                    143   General Practice      Pending
# 7305                                    136   General Practice     Approved
# 7578                                    134          Neurology     Approved
# 7594                                    141          Neurology     Approved
# 8158                                    141  Internal Medicine     Rejected
# 8328                                    142  Internal Medicine     Approved
# 8791                                    131        Orthopedics     Rejected
# 9551                                    137        Orthopedics     Approved
#
#       Is_Fraud  Length_of_Stay  Visit_Type  Chronic_Condition_Flag  \
# 951          1               3  Outpatient                       1
# 1232         1               0   Emergency                       0
# 1316         0               3   Emergency                       1
# 1450         0               0   Inpatient                       1
# 1529         0               3  Outpatient                       0
# 2968         0               0   Inpatient                       0
# 4260         0               3   Emergency                       1
# 4438         1               0   Inpatient                       0
# 4714         1               3   Inpatient                       1
# 4784         0               3   Inpatient                       1
# 5166         0               0   Inpatient                       1
# 5855         1               2  Outpatient                       1
# 5928         0               0   Inpatient                       0
# 5938         0               5   Inpatient                       0
# 6284         0               5   Emergency                       0
# 6471         0               1   Emergency                       0
# 6710         1               0  Outpatient                       1
# 7305         0               3   Emergency                       1
# 7578         0               5   Emergency                       1
# 7594         0               5  Outpatient                       0
# 8158         1               3   Emergency                       1
# 8328         1               0   Emergency                       1
# 8791         0               0   Emergency                       0
# 9551         0               3  Outpatient                       0
#
#       Claim_Submission_mth  Claim_Submission_yr
# 951                      9                 2024
# 1232                     5                 2023
# 1316                     2                 2022
# 1450                     1                 2023
# 1529                     9                 2024
# 2968                     7                 2022
# 4260                     2                 2021
# 4438                     7                 2022
# 4714                     2                 2023
# 4784                    12                 2021
# 5166                    10                 2024
# 5855                     2                 2021
# 5928                     6                 2021
# 5938                     6                 2021
# 6284                     1                 2023
# 6471                     6                 2023
# 6710                     7                 2021
# 7305                     8                 2022
# 7578                     2                 2021
# 7594                     4                 2024
# 8158                    11                 2022
# 8328                    10                 2022
# 8791                    10                 2022
# 9551                     3                 2024

# %%
fig, ax = plt.subplots()

sns.boxplot(x=df["Days_Between_Service_and_Claim"])

ax.set_facecolor((0, 0, 0, 0)) #Transparent Background
fig.patch.set_alpha(0.0)

plt.title("Boxplot of Days End to End Services")
plt.show()

# %%
q1_num_clm = df["Number_of_Claims_Per_Provider_Monthly"].quantile(0.25)
q3_num_clm = df["Number_of_Claims_Per_Provider_Monthly"].quantile(0.75)

iqr_num_clm = q3_num_clm - q1_num_clm

upper_bound_num_clm = q3_num_clm + (1.5 * iqr_num_clm)

df_clean = df[df['Number_of_Claims_Per_Provider_Monthly'] <= upper_bound_num_clm]
df_clean
# Out:
#       Patient_Age Patient_Gender  Claim_Amount  Approved_Amount  \
# 0              37           Male        443.51           393.16
# 1              21         Female        467.50           461.33
# 2              78         Female        591.69           530.06
# 3              65           Male        235.15           189.11
# 4              36           Male        487.96           369.91
# ...           ...            ...           ...              ...
# 9994           50         Female        395.58           309.53
# 9996           66           Male        219.73           191.89
# 9997           43         Female        505.24           447.94
# 9998           39         Female        564.25           507.18
# 9999           26           Male        564.52           563.74
#
#      Insurance_Type Claim_Submission_Date  Days_Between_Service_and_Claim  \
# 0          Medicaid            2024-09-01                              13
# 1          Self-Pay            2022-09-05                               5
# 2          Medicaid            2022-04-11                              29
# 3           Private            2023-10-11                              22
# 4           Private            2023-09-05                              21
# ...             ...                   ...                             ...
# 9994       Medicaid            2024-01-22                              18
# 9996       Self-Pay            2023-01-04                               6
# 9997       Medicare            2024-06-30                               6
# 9998       Medicare            2022-03-15                               8
# 9999       Medicaid            2023-01-24                               2
#
#       Number_of_Claims_Per_Provider_Monthly Provider_Specialty Claim_Status  \
# 0                                        70         Cardiology     Approved
# 1                                        62   General Practice      Pending
# 2                                        60         Cardiology      Pending
# 3                                        70   General Practice     Approved
# 4                                        67        Pulmonology     Approved
# ...                                     ...                ...          ...
# 9994                                     82        Pulmonology     Approved
# 9996                                     73        Orthopedics     Approved
# 9997                                     59          Neurology     Rejected
# 9998                                     55         Cardiology      Pending
# 9999                                     86          Neurology     Approved
#
#       Is_Fraud  Length_of_Stay  Visit_Type  Chronic_Condition_Flag  \
# 0            0               0  Outpatient                       1
# 1            0               5   Inpatient                       1
# 2            0               5   Inpatient                       1
# 3            0               0   Emergency                       0
# 4            0               5   Inpatient                       0
# ...        ...             ...         ...                     ...
# 9994         0               0  Outpatient                       1
# 9996         0               5   Inpatient                       0
# 9997         0               5   Emergency                       1
# 9998         0               5   Emergency                       0
# 9999         0               3  Outpatient                       0
#
#       Claim_Submission_mth  Claim_Submission_yr
# 0                        9                 2024
# 1                        9                 2022
# 2                        4                 2022
# 3                       10                 2023
# 4                        9                 2023
# ...                    ...                  ...
# 9994                     1                 2024
# 9996                     1                 2023
# 9997                     6                 2024
# 9998                     3                 2022
# 9999                     1                 2023
#
# [9183 rows x 16 columns]

# %%
# df_clean[['Insurance_Type', 'Provider_Specialty']] = df_clean[['Insurance_Type', 'Provider_Specialty']].fillna(df_clean[['Insurance_Type', 'Provider_Specialty']].mode())

# %%
df_cleans = df_clean.dropna().reset_index(drop=True)
df_cleans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8555 entries, 0 to 8554
# Data columns (total 16 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Patient_Age                            8555 non-null   int64
#  1   Patient_Gender                         8555 non-null   object
#  2   Claim_Amount                           8555 non-null   float64
#  3   Approved_Amount                        8555 non-null   float64
#  4   Insurance_Type                         8555 non-null   object
#  5   Claim_Submission_Date                  8555 non-null   datetime64[ns]
#  6   Days_Between_Service_and_Claim         8555 non-null   int64
#  7   Number_of_Claims_Per_Provider_Monthly  8555 non-null   int64
#  8   Provider_Specialty                     8555 non-null   object
#  9   Claim_Status                           8555 non-null   object
#  10  Is_Fraud                               8555 non-null   int64
#  11  Length_of_Stay                         8555 non-null   int64
#  12  Visit_Type                             8555 non-null   object
#  13  Chronic_Condition_Flag                 8555 non-null   int64
#  14  Claim_Submission_mth                   8555 non-null   int32
#  15  Claim_Submission_yr                    8555 non-null   int32
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(6), object(5)
# memory usage: 1002.7+ KB

# %%
fig, ax = plt.subplots(figsize=(10, 5))

sns.countplot(df[(df['Claim_Status'] == 'Approved') | (df['Claim_Status'] == 'Rejected')], x='Is_Fraud', ax=ax)

ax.set_facecolor((0, 0, 0, 0)) #Transparent Background
fig.patch.set_alpha(0.0)

plt.title("Fraud")
plt.xlabel("Fraud")
plt.ylabel("Count")
plt.show()

# %%
df_cleans.drop(['Claim_Submission_Date', 'Approved_Amount'], axis=1, inplace=True)

# %% [markdown]
# ### Handling Imbalance Data

# %%
from imblearn.over_sampling import SMOTENC

TRAIN = df_cleans[(df_cleans['Claim_Status'] == 'Approved') | (df_cleans['Claim_Status'] == 'Rejected')].drop(['Claim_Status'], axis=1)
TEST = df_cleans[df_cleans['Claim_Status'] == 'Pending'].drop(['Claim_Status'], axis=1)

X_train = TRAIN.drop(['Is_Fraud'], axis=1)
X_test = TEST.drop(['Is_Fraud'], axis=1)

y_train = TRAIN['Is_Fraud']
y_test = TEST['Is_Fraud']

categorical_indices = [
    X_train.columns.get_loc(col)
    for col in X_train.select_dtypes('object').columns
]

smote_nc = SMOTENC(
    categorical_features=categorical_indices,
    random_state=22
)

X_resampled, y_resampled = smote_nc.fit_resample(X_train, y_train)

# %% [markdown]
# ### Data Preparation & Train Data

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from xgboost import XGBClassifier

scaler = StandardScaler()
ohe = OneHotEncoder(drop='first')

numeric_features = X_train.select_dtypes('number').columns
categorical_features = X_train.select_dtypes('object').columns

xgb = XGBClassifier(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=4,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=22
)

preprocessor = ColumnTransformer([
    ('num', scaler, numeric_features),
    ('cat', ohe, categorical_features)
])

pipeline = Pipeline([
    ('pre', preprocessor),
    ('model', xgb)
])

pipeline.fit(X_resampled, y_resampled)

y_pred = pipeline.predict(X_test)

# %%
# Evaluate
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, recall_score

target_names = ['Not Fraud', 'Fraud']
print(classification_report(y_test, y_pred, target_names=target_names))

print('Recall Score: ', recall_score(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=pipeline.classes_)
disp.plot()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.94      0.93      0.93       804
#        Fraud       0.73      0.76      0.74       201
#
#     accuracy                           0.90      1005
#    macro avg       0.83      0.85      0.84      1005
# weighted avg       0.90      0.90      0.90      1005
#
# Recall Score:  0.7611940298507462

# %%
# Feature Importance

model = pipeline.named_steps['model']

importance = model.feature_importances_

feature_names = pipeline.named_steps[
    'pre'
].get_feature_names_out()

feature_importance = pd.DataFrame({
    'feature': feature_names,
    'importance': importance
})

feature_importance = feature_importance.sort_values(
    by='importance',
    ascending=False
).reset_index(drop=True)

print(feature_importance.head(10))
# Out:
#                                      feature  importance
# 0        num__Days_Between_Service_and_Claim    0.563942
# 1                num__Chronic_Condition_Flag    0.089693
# 2                   num__Claim_Submission_yr    0.058809
# 3                          num__Claim_Amount    0.043151
# 4                        num__Length_of_Stay    0.040821
# 5  cat__Provider_Specialty_Internal Medicine    0.019975
# 6                  num__Claim_Submission_mth    0.019916
# 7               cat__Insurance_Type_Self-Pay    0.018443
# 8        cat__Provider_Specialty_Pulmonology    0.016244
# 9               cat__Insurance_Type_Medicare    0.014961

# %% [markdown]
# ### **Deployment**

# %%
# Streamlit
